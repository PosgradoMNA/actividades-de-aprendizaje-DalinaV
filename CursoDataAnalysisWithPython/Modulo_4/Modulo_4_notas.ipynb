# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Inteligencia Artificial y Aprendizaje Automático**
# ###Tecnológico de Monterrey
# ###Profra. Maria de la Paz Rico
# #Alumna: Dalina Aidee Villa Ocelotl
# #Matricula: A01793258

# %% [markdown]
# ![Captura de pantalla 2022-10-15 222657.png](data:image/png;base64,...)

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# Un modelo es una ecuacion que permite definir Y como la variable dependiente de las caracteriticas X

# %% [markdown]
# ![3.png](data:image/png;base64,...)

# %% [markdown]
# Con estos tipos de regresion podemos obtener curvas que se apeguen mas a los datos

# %% [markdown]
# ![4.png](data:image/png;base64,...)

# %% [markdown]
# Se genera una ecuacion entrenando con datos y despues se valida esa ecuacion con datos

# %% [markdown]
# ![5.png](data:image/png;base64,...)

# %% [markdown]
# ![6.png](data:image/png;base64,...)

# %% [markdown]
# ![7.png](data:image/png;base64,...)

# %% [markdown]
# ![8.png](data:image/png;base64,...)

# %% [markdown]
# ![9.png](data:image/png;base64,...)

# %% [markdown]
# ![10.png](data:image/png;base64,...)

# %% [markdown]
# ![11.png](data:image/png;base64,...)

# %% [markdown]
# Esto aplica para dos diemnsiones o tres dimensiones etc.

# %% [markdown]
# ![12.png](data:image/png;base64,...)

# %% [markdown]
# ![13.png](data:image/png;base64,...)

# %% [markdown]
# ![14.png](data:image/png;base64,...)

# %% [markdown]
# ![15.png](data:image/png;base64,...)

# %% [markdown]
# ![16.png](data:image/png;base64,...)

# %% [markdown]
# ![17.png](data:image/png;base64,...)

# %% [markdown]
# ![18.png](data:image/png;base64,...)

# %% [markdown]
# ![19.png](data:image/png;base64,...)

# %% [markdown]
# ![20.png](data:image/png;base64,...)

# %% [markdown]
# ![21.png](data:image/png;base64,...)

# %% [markdown]
# En conclusion de acuerdo a la cantidad de datos y a como se distribuyen los datos es que se debe elegir el modelo a considerar
